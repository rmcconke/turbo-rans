# %%
import numpy as np
import os
import fileinput
import sys
import pandas as pd
import matplotlib.pyplot as plt

from utilities.foam_automation.caserunner import run_until_convergence, get_endtime
from utilities.foam_automation.computeFoamLossFunc import computeFoamFieldLossFunc
from utilities.foam_automation.set_foam_coeff import set_foam_coef

from utilities.json_io import write_suggestion, write_json, load_coeff_default, load_coeff_bounds, load_history_loss_log, load_suggestion

from utilities.control import initialize
from update_history import register_score
from suggest_coeffs import suggest
import random

# %% [markdown]
# # Grid search

# %%
a1_vec = np.around(np.linspace(0.15,0.8,300),4)
betastar_vec = np.around(np.linspace(0.045,0.25,100),4)
history_directory = '/home/ryley/WDK/ML/foam/run/turbo-rans/gridsearch/tuner'

a1_combined, betastar_combined = np.meshgrid(np.around(np.linspace(0.24,0.6,30),4),
                                             np.around(np.linspace(0.045,0.14,30),4))
a1_combined = a1_combined.flatten()
betastar_combined = betastar_combined.flatten()

# %%
# Run simulation loop    
for betastar in betastar_vec:
    casedir = f'foam/gridsearch/betaStar_phll/case_1p0_betastar_{betastar}'
    os.system(f'cp -r foam/gridsearch/betaStar_phll/case_1p0_template {casedir}')
    search_point = {'betaStar': betastar}
    write_suggestion(directory = history_directory, suggestion = search_point)
    set_foam_coef(casedir,search_point)
    #Uncomment to run
    #last_time = run_until_convergence(case = casedir, n_proc = 16)
# Out:
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json

# %%
# Run simulation loop (already run)
for a1 in a1_vec:
    casedir = f'foam/gridsearch_a1_phll/case_1p0_a1_{a1}'
    os.system(f'cp -r foam/gridsearch_a1_phll/case_1p0_template {casedir}')
    search_point = {'a1': a1}
    write_suggestion(directory = history_directory, suggestion = search_point)
    set_foam_coef(casedir,search_point)
    #Uncomment to run
    #last_time = run_until_convergence(case = casedir, n_proc = 16)

# %%
for a1, betastar in zip(a1_combined, betastar_combined):
    casedir = f'foam/gridsearch/a1_betaStar_phll/case_1p0_a1_{a1}_betaStar_{betastar}'
    os.system(f'cp -r foam/gridsearch/a1_betaStar_phll/case_1p0_template {casedir}')
    search_point = {'a1': a1,
                    'betaStar': betastar}
    write_suggestion(directory = history_directory, suggestion = search_point)
    set_foam_coef(casedir,search_point)
    #Uncomment to run
    #last_time = run_until_convergence(case = casedir, n_proc = 16)
# Out:
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Exception in thread Thread-5169:
# Traceback (most recent call last):
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_common.py", line 442, in wrapper
#     ret = self._cache[fun]
# AttributeError: _cache
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_pslinux.py", line 1642, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_common.py", line 445, in wrapper
#     return fun(self)
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_pslinux.py", line 1684, in _parse_stat_file
#     data = bcat("%s/%s/stat" % (self._procfs_path, self.pid))
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_common.py", line 775, in bcat
#     return cat(fname, fallback=fallback, _open=open_binary)
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_common.py", line 763, in cat
#     with _open(fname) as f:
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_common.py", line 727, in open_binary
#     return open(fname, "rb", buffering=FILE_READ_BUFFER_SIZE)
# FileNotFoundError: [Errno 2] No such file or directory: '/proc/32885/stat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/__init__.py", line 361, in _init
#     self.create_time()
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/__init__.py", line 714, in create_time
#     self._create_time = self._proc.create_time()
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_pslinux.py", line 1642, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_pslinux.py", line 1852, in create_time
#     ctime = float(self._parse_stat_file()['create_time'])
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_pslinux.py", line 1649, in wrapper
#     raise NoSuchProcess(self.pid, self._name)
# psutil.NoSuchProcess: process no longer exists (pid=32885)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.9/threading.py", line 1286, in run
#     self.function(*self.args, **self.kwargs)
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/PyFoam/Execution/FoamThread.py", line 86, in getLinuxMem
#     me=psutil.Process(thrd.threadPid)
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/__init__.py", line 332, in __init__
#     self._init(pid)
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/__init__.py", line 373, in _init
#     raise NoSuchProcess(pid, msg='process PID not found')
# psutil.NoSuchProcess: process PID not found (pid=32885)
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Exception in thread Thread-15528:
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.9/threading.py", line 1286, in run
#     self.function(*self.args, **self.kwargs)
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/PyFoam/Execution/FoamThread.py", line 87, in getLinuxMem
#     procs=[me]+me.children(True)
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/__init__.py", line 277, in wrapper
#     raise NoSuchProcess(self.pid, self._name, msg=msg)
# psutil.NoSuchProcess: process no longer exists (pid=657190)
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json

# %%
# Calculate errors loop
# Keep this cell, delete next cell if this works

ref_df = pd.read_csv('foam/gridsearch/tuner/refdata.csv')
initialize(directory = history_directory,
           coeff_bounds = {'a1':[min(a1_vec),max(a1_vec)]},
           coeff_default = {'a1': 0.31},
           restart = True)

for a1 in a1_vec:
    casedir = f'foam/gridsearch/a1_phll/case_1p0_a1_{a1}'
    foamLoss = computeFoamFieldLossFunc(foamdir=casedir,
                                        ref_df=ref_df,
                                        interp_method='nearest')
    search_point = {'a1': a1}
    write_suggestion(directory = history_directory, suggestion = search_point)
    last_time = get_endtime(case=casedir)
    
    save_dict = {
        'params': search_point,
        'foam_mse_U_componentwise_2Dxy': -foamLoss.foam_mse_U_componentwise_2Dxy(foamtime=last_time),
        'foam_mse_U_magnitude_2Dxy': -foamLoss.foam_mse_U_magnitude_2Dxy(foamtime=last_time),
        'foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean': -foamLoss.foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory)),
        'foam_multi_mape_U_magnitude_2Dxy_relcoeff_mean': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory)),
        'foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory)),
        'foam_multi_mape_U_magnitude_2Dxy_mape_k': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k(foamtime=last_time),
        'foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda_0p25': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory),lda=0.25),
        'foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda_0p5': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                            coeff_dict=search_point,
                                                            coeff_default=load_coeff_default(directory=history_directory),lda=0.5)
    }
    
    write_json(history_directory, save_dict, 'lossfuncs_gridsearch_a1.json', append=True)
# Out:
# Saving coeff_bounds to foam/gridsearch/tuner/coeff_bounds.json
# Saving coeff_default to foam/gridsearch/tuner/coeff_default.json
# Removing old history and suggestion files....
# Could not remove a file, it might not exist to start....
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json

# %%
# Calculate errors loop
# Keep this cell, delete next cell if this works

ref_df = pd.read_csv('foam/gridsearch/tuner/refdata.csv')
initialize(directory = history_directory,
           coeff_bounds = {'betaStar':[min(betastar_vec),max(betastar_vec)]},
           coeff_default = {'betaStar': 0.09},
           restart = True)

for betastar in betastar_vec:
    casedir = f'foam/gridsearch/betaStar_phll/case_1p0_betastar_{betastar}'
    foamLoss = computeFoamFieldLossFunc(foamdir=casedir,
                                        ref_df=ref_df,
                                        interp_method='nearest')
    search_point = {'betaStar': betastar}
    write_suggestion(directory = history_directory, suggestion = search_point)
    last_time = get_endtime(case=casedir)
    
    save_dict = {
        'params': search_point,
        'foam_mse_U_componentwise_2Dxy': -foamLoss.foam_mse_U_componentwise_2Dxy(foamtime=last_time),
        'foam_mse_U_magnitude_2Dxy': -foamLoss.foam_mse_U_magnitude_2Dxy(foamtime=last_time),
        'foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean': -foamLoss.foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory)),
        'foam_multi_mape_U_magnitude_2Dxy_relcoeff_mean': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory)),
        'foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory)),
        'foam_multi_mape_U_magnitude_2Dxy_mape_k': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k(foamtime=last_time),
        'foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda_0p25': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory),lda=0.25),
        'foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda_0p5': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                            coeff_dict=search_point,
                                                            coeff_default=load_coeff_default(directory=history_directory),lda=0.5)
    }
    
    write_json(history_directory, save_dict, 'lossfuncs_gridsearch_betastar.json', append=True)
# Out:
# Saving coeff_bounds to foam/gridsearch/tuner/coeff_bounds.json
# Saving coeff_default to foam/gridsearch/tuner/coeff_default.json
# Removing old history and suggestion files....
# Could not remove a file, it might not exist to start....
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json

# %%
# Calculate errors loop
# Keep this cell, delete next cell if this works

ref_df = pd.read_csv('foam/gridsearch/tuner/refdata.csv')
initialize(directory = history_directory,
           coeff_bounds = {'betaStar':[min(betastar_vec),max(betastar_vec)]},
           coeff_default = {'betaStar': 0.09},
           restart = True)

for a1, betastar in zip(a1_combined, betastar_combined):
    casedir = f'foam/gridsearch/a1_betaStar_phll/case_1p0_a1_{a1}_betaStar_{betastar}'
    foamLoss = computeFoamFieldLossFunc(foamdir=casedir,
                                        ref_df=ref_df,
                                        interp_method='nearest')
    search_point = {'a1': a1,
                    'betaStar': betastar}
    write_suggestion(directory = history_directory, suggestion = search_point)
    last_time = get_endtime(case=casedir)
    
    save_dict = {
        'params': search_point,
        'foam_mse_U_componentwise_2Dxy': -foamLoss.foam_mse_U_componentwise_2Dxy(foamtime=last_time),
        'foam_mse_U_magnitude_2Dxy': -foamLoss.foam_mse_U_magnitude_2Dxy(foamtime=last_time),
        'foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean': -foamLoss.foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory)),
        'foam_multi_mape_U_magnitude_2Dxy_relcoeff_mean': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory)),
        'foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory)),
        'foam_multi_mape_U_magnitude_2Dxy_mape_k': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k(foamtime=last_time),
        'foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda_0p25': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory),lda=0.25),
        'foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda_0p5': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                            coeff_dict=search_point,
                                                            coeff_default=load_coeff_default(directory=history_directory),lda=0.5)
    }
    
    write_json(history_directory, save_dict, 'lossfuncs_gridsearch_a1_betastar.json', append=True)
# Out:
# Saving coeff_bounds to foam/gridsearch/tuner/coeff_bounds.json
# Saving coeff_default to foam/gridsearch/tuner/coeff_default.json
# Removing old history and suggestion files....
# Could not remove a file, it might not exist to start....
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json

# %%
losses_dict = load_history_loss_log(history_directory, 'lossfuncs_gridsearch_a1_betastar.json')
print(len(losses_dict['target']))
plt.scatter(losses_dict['betaStar'],losses_dict['foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda_0p25'],label=r'$F_6 (\lambda=0.25)$')
#plt.scatter(losses_dict['a1'],losses_dict['foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda_0p5'],label=r'$F_6 (\lambda=0.5)$')
#plt.scatter(losses_dict['a1'],losses_dict['foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean'],label=r'$F_6 (\lambda=1)$')

plt.legend()
plt.xlabel(r'$\beta^*$')
plt.ylabel(r'$F$')
# Out:
# 0
# Text(0, 0.5, '$F$')

# %%
from matplotlib import cm
fig, ax = plt.subplots(figsize=(10,10),subplot_kw={"projection": "3d"})
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_trisurf(losses_dict['a1'], losses_dict['betaStar'], 
                       losses_dict['foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda_0p25'], cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
ax.set_xlabel('a1')
ax.set_ylabel('betaStar')
print(max(losses_dict['foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda_0p25']))
# Out:
# -0.5134817416206452

# %%
from matplotlib import cm
fig, ax = plt.subplots(figsize=(10,10))
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.tricontourf(losses_dict['a1'], losses_dict['betaStar'], 
                       losses_dict['foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda_0p25'], cmap=cm.coolwarm,
                       linewidth=0, antialiased=False,levels=100)
ax.set_xlabel('a1')
ax.set_ylabel('betaStar')
# Out:
# /tmp/ipykernel_2806767/123918140.py:10: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   surf = ax.tricontourf(losses_dict['a1'], losses_dict['betaStar'],
# Text(0, 0.5, 'betaStar')

# %% [markdown]
# # Bayesian optimization

# %%
# Run simulation loop
foamdir = '/home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter'
tunerdir = os.path.join(foamdir,'tuner')
iterations=20
ref_df = pd.read_csv(os.path.join(tunerdir,'refdata.csv'))
initialize(directory = tunerdir,
           coeff_bounds = None,
           coeff_default = None,
           restart = True)

foamLoss = computeFoamFieldLossFunc(foamdir=foamdir,
                                    ref_df=ref_df,
                                    interp_method='nearest')
                                
for i in range(iterations):
    if i == 0:
        search_point = load_coeff_default(directory=tunerdir)
        write_suggestion(directory=tunerdir, suggestion=search_point)
    else:
        suggest(directory=tunerdir,
                           random_state=7)
        search_point = load_suggestion(directory=tunerdir)
    print(search_point)
    set_foam_coef(foamdir,search_point)
    last_time = run_until_convergence(case=foamdir, n_proc = 16)
    score = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                            coeff_dict=search_point,
                                                                            coeff_default=load_coeff_default(directory=tunerdir),lda=0.5)   

    register_score(score=score, directory=tunerdir)
# Out:
# Did not get coefficient bounds dict for initialization, assuming coeff_bounds.json exists in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner
# Did not get coefficient default dict for initialization, assuming coeff_default.json exists in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner or is not needed
# Removing old history and suggestion files....
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.31}
# No history file exists at /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json, creating and registering first point
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.155}
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.3100270404686694}
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.3976126525741651}
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.465}
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.4284573349649169}
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.37953472200486515}
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.3883956122811422}
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.38903140642281214}
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.38902987454459115}
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.38855941219650536}
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.3905676397514715}
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.38726548805155026}
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.39035653569722295}
# Exception in thread Thread-245:
# Traceback (most recent call last):
#   File "/home/ryley/.local/lib/python3.9/site-packages/psutil/_common.py", line 442, in wrapper
#     ret = self._cache[fun]
# AttributeError: _cache
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ryley/.local/lib/python3.9/site-packages/psutil/_pslinux.py", line 1642, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/home/ryley/.local/lib/python3.9/site-packages/psutil/_common.py", line 445, in wrapper
#     return fun(self)
#   File "/home/ryley/.local/lib/python3.9/site-packages/psutil/_pslinux.py", line 1684, in _parse_stat_file
#     data = bcat("%s/%s/stat" % (self._procfs_path, self.pid))
#   File "/home/ryley/.local/lib/python3.9/site-packages/psutil/_common.py", line 775, in bcat
#     return cat(fname, fallback=fallback, _open=open_binary)
#   File "/home/ryley/.local/lib/python3.9/site-packages/psutil/_common.py", line 763, in cat
#     with _open(fname) as f:
#   File "/home/ryley/.local/lib/python3.9/site-packages/psutil/_common.py", line 727, in open_binary
#     return open(fname, "rb", buffering=FILE_READ_BUFFER_SIZE)
# FileNotFoundError: [Errno 2] No such file or directory: '/proc/31057/stat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ryley/.local/lib/python3.9/site-packages/psutil/__init__.py", line 361, in _init
#     self.create_time()
#   File "/home/ryley/.local/lib/python3.9/site-packages/psutil/__init__.py", line 714, in create_time
#     self._create_time = self._proc.create_time()
#   File "/home/ryley/.local/lib/python3.9/site-packages/psutil/_pslinux.py", line 1642, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/home/ryley/.local/lib/python3.9/site-packages/psutil/_pslinux.py", line 1852, in create_time
#     ctime = float(self._parse_stat_file()['create_time'])
#   File "/home/ryley/.local/lib/python3.9/site-packages/psutil/_pslinux.py", line 1649, in wrapper
#     raise NoSuchProcess(self.pid, self._name)
# psutil.NoSuchProcess: process no longer exists (pid=31057)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.9/threading.py", line 1286, in run
#     self.function(*self.args, **self.kwargs)
#   File "/home/ryley/.local/lib/python3.9/site-packages/PyFoam/Execution/FoamThread.py", line 86, in getLinuxMem
#     me=psutil.Process(thrd.threadPid)
#   File "/home/ryley/.local/lib/python3.9/site-packages/psutil/__init__.py", line 332, in __init__
#     self._init(pid)
#   File "/home/ryley/.local/lib/python3.9/site-packages/psutil/__init__.py", line 373, in _init
#     raise NoSuchProcess(pid, msg='process PID not found')
# psutil.NoSuchProcess: process PID not found (pid=31057)
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.3874036815137883}
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.3901686072770878}
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.3874835390660492}
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.38771974231962636}
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.39015504214861857}
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/suggestion.json
# {'a1': 0.38769580905316103}
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/bayesian_a1_phll/case_1p0_lda0p5_20iter/tuner/history.json

# %%
# throw me away
foamdir = '/home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/case_1p0_errortest/'
tunerdir = os.path.join(foamdir,'tuner')
iterations=20
ref_df = pd.read_csv(os.path.join(tunerdir,'refdata.csv'))
initialize(directory = tunerdir,
           coeff_bounds = None,
           coeff_default = None,
           restart = True)

foamLoss = computeFoamFieldLossFunc(foamdir=foamdir,
                                    ref_df=ref_df,
                                    interp_method='nearest')
search_point = {'a1':0.31,'betaStar':0.09}
print(load_coeff_default(directory=tunerdir))
write_suggestion(directory=tunerdir, suggestion=search_point)
set_foam_coef(foamdir, search_point)
last_time = run_until_convergence(case=foamdir, n_proc = 10)
score = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                        coeff_dict=search_point,
                                                                        coeff_default=load_coeff_default(directory=tunerdir),lda=0.5)  
print(score)
# Out:
# Did not get coefficient bounds dict for initialization, assuming coeff_bounds.json exists in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/case_1p0_errortest/tuner
# Did not get coefficient default dict for initialization, assuming coeff_default.json exists in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/case_1p0_errortest/tuner or is not needed
# Removing old history and suggestion files....
# Could not remove a file, it might not exist to start....
# {'a1': 0.31, 'betaStar': 0.09}
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/case_1p0_errortest/tuner/suggestion.json
# -1.0156718130615825

# %% [markdown]
# ## Search for optimal optimizer hyperparameters

# %%
def write_coefficient_run_case_register_score(foamLoss, foamdir, tunerdir, search_point):
    set_foam_coef(foamdir, search_point)
    last_time = run_until_convergence(case=foamdir, n_proc = 10)
    score = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                            coeff_dict=search_point,
                                                                            coeff_default=load_coeff_default(directory=tunerdir),
                                                                            lda=0.5)   

    register_score(score=score, directory=tunerdir)
    return score

# %%
opt_a1 = 0.3393
opt_betastar = 0.0745
opt_score = -0.40044740367131915
utility = 'ei'
for xi in [1E-4,1E-3,1E-2,1E-1]:
    for n in range(10):
        casedir = f'/home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_{xi}_case_1p0_{n}'
        os.system(f'cp -r /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/case_1p0_template {casedir}')
        tunerdir = os.path.join(casedir,'tuner')
        ref_df = pd.read_csv(os.path.join(tunerdir,'refdata.csv'))

        initialize(directory = tunerdir,
                   coeff_bounds = None,
                   coeff_default = None,
                   restart = True)

        foamLoss = computeFoamFieldLossFunc(foamdir=casedir,
                                            ref_df=ref_df,
                                            interp_method='nearest')
        
        search_point = load_coeff_default(directory=tunerdir)
        write_suggestion(tunerdir, search_point)
        score = write_coefficient_run_case_register_score(foamLoss,casedir,tunerdir,search_point)
        i=0
        distance_a1 = abs(search_point['a1']-opt_a1)
        distance_betastar = abs(search_point['betaStar']-opt_betastar)
        while distance_a1 > 0.05*abs(opt_a1) or distance_betastar > 0.05*abs(opt_betastar):
            score_old = score
            suggest(directory=tunerdir,
                       random_state=n,
                   utility_kind=utility,
                   xi = xi)
            search_point = load_suggestion(directory=tunerdir)
            distance_a1 = abs(search_point['a1']-opt_a1)
            distance_betastar = abs(search_point['betaStar']-opt_betastar)
            score = write_coefficient_run_case_register_score(foamLoss,casedir,tunerdir,search_point)
            if (abs(score - score_old) < 1E-11) or (i > 100):
                print('-----> CONVERVED, BREAKING')
                break
# Out:
# Did not get coefficient bounds dict for initialization, assuming coeff_bounds.json exists in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner
# Did not get coefficient default dict for initialization, assuming coeff_default.json exists in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner or is not needed
# Removing old history and suggestion files....
# Could not remove a file, it might not exist to start....
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# No history file exists at /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json, creating and registering first point
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Exception in thread Thread-36000:
# Traceback (most recent call last):
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 442, in wrapper
#     ret = self._cache[fun]
# AttributeError: 'Process' object has no attribute '_cache'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1642, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 445, in wrapper
#     return fun(self)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1684, in _parse_stat_file
#     data = bcat("%s/%s/stat" % (self._procfs_path, self.pid))
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 775, in bcat
#     return cat(fname, fallback=fallback, _open=open_binary)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 763, in cat
#     with _open(fname) as f:
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 727, in open_binary
#     return open(fname, "rb", buffering=FILE_READ_BUFFER_SIZE)
# FileNotFoundError: [Errno 2] No such file or directory: '/proc/3206374/stat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 361, in _init
#     self.create_time()
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 714, in create_time
#     self._create_time = self._proc.create_time()
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1642, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1852, in create_time
#     ctime = float(self._parse_stat_file()['create_time'])
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1649, in wrapper
#     raise NoSuchProcess(self.pid, self._name)
# psutil.NoSuchProcess: process no longer exists (pid=3206374)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 1371, in run
#     self.function(*self.args, **self.kwargs)
#   File "/home/ryley/.local/lib/python3.10/site-packages/PyFoam/Execution/FoamThread.py", line 86, in getLinuxMem
#     me=psutil.Process(thrd.threadPid)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 332, in __init__
#     self._init(pid)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 373, in _init
#     raise NoSuchProcess(pid, msg='process PID not found')
# psutil.NoSuchProcess: process PID not found (pid=3206374)
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Exception in thread Thread-36489:
# Traceback (most recent call last):
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 442, in wrapper
#     ret = self._cache[fun]
# AttributeError: 'Process' object has no attribute '_cache'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1642, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 445, in wrapper
#     return fun(self)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1684, in _parse_stat_file
#     data = bcat("%s/%s/stat" % (self._procfs_path, self.pid))
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 775, in bcat
#     return cat(fname, fallback=fallback, _open=open_binary)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 763, in cat
#     with _open(fname) as f:
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 727, in open_binary
#     return open(fname, "rb", buffering=FILE_READ_BUFFER_SIZE)
# FileNotFoundError: [Errno 2] No such file or directory: '/proc/3211650/stat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 361, in _init
#     self.create_time()
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 714, in create_time
#     self._create_time = self._proc.create_time()
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1642, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1852, in create_time
#     ctime = float(self._parse_stat_file()['create_time'])
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1649, in wrapper
#     raise NoSuchProcess(self.pid, self._name)
# psutil.NoSuchProcess: process no longer exists (pid=3211650)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 1371, in run
#     self.function(*self.args, **self.kwargs)
#   File "/home/ryley/.local/lib/python3.10/site-packages/PyFoam/Execution/FoamThread.py", line 86, in getLinuxMem
#     me=psutil.Process(thrd.threadPid)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 332, in __init__
#     self._init(pid)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 373, in _init
#     raise NoSuchProcess(pid, msg='process PID not found')
# psutil.NoSuchProcess: process PID not found (pid=3211650)
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_0/tuner/history.json
# Did not get coefficient bounds dict for initialization, assuming coeff_bounds.json exists in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner
# Did not get coefficient default dict for initialization, assuming coeff_default.json exists in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner or is not needed
# Removing old history and suggestion files....
# Could not remove a file, it might not exist to start....
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# No history file exists at /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json, creating and registering first point
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Exception in thread Thread-37134:
# Traceback (most recent call last):
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 442, in wrapper
#     ret = self._cache[fun]
# AttributeError: 'Process' object has no attribute '_cache'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1642, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 445, in wrapper
#     return fun(self)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1684, in _parse_stat_file
#     data = bcat("%s/%s/stat" % (self._procfs_path, self.pid))
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 775, in bcat
#     return cat(fname, fallback=fallback, _open=open_binary)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 763, in cat
#     with _open(fname) as f:
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 727, in open_binary
#     return open(fname, "rb", buffering=FILE_READ_BUFFER_SIZE)
# FileNotFoundError: [Errno 2] No such file or directory: '/proc/3218507/stat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 361, in _init
#     self.create_time()
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 714, in create_time
#     self._create_time = self._proc.create_time()
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1642, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1852, in create_time
#     ctime = float(self._parse_stat_file()['create_time'])
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1649, in wrapper
#     raise NoSuchProcess(self.pid, self._name)
# psutil.NoSuchProcess: process no longer exists (pid=3218507)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 1371, in run
#     self.function(*self.args, **self.kwargs)
#   File "/home/ryley/.local/lib/python3.10/site-packages/PyFoam/Execution/FoamThread.py", line 86, in getLinuxMem
#     me=psutil.Process(thrd.threadPid)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 332, in __init__
#     self._init(pid)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 373, in _init
#     raise NoSuchProcess(pid, msg='process PID not found')
# psutil.NoSuchProcess: process PID not found (pid=3218507)
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_1/tuner/history.json
# Did not get coefficient bounds dict for initialization, assuming coeff_bounds.json exists in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner
# Did not get coefficient default dict for initialization, assuming coeff_default.json exists in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner or is not needed
# Removing old history and suggestion files....
# Could not remove a file, it might not exist to start....
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# No history file exists at /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json, creating and registering first point
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_2/tuner/history.json
# Did not get coefficient bounds dict for initialization, assuming coeff_bounds.json exists in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner
# Did not get coefficient default dict for initialization, assuming coeff_default.json exists in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner or is not needed
# Removing old history and suggestion files....
# Could not remove a file, it might not exist to start....
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# No history file exists at /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json, creating and registering first point
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.0001_case_1p0_3/tuner/suggestion.json
# ...
#     return fun(self, *args, **kwargs)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 445, in wrapper
#     return fun(self)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1684, in _parse_stat_file
#     data = bcat("%s/%s/stat" % (self._procfs_path, self.pid))
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 775, in bcat
#     return cat(fname, fallback=fallback, _open=open_binary)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 763, in cat
#     with _open(fname) as f:
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 727, in open_binary
#     return open(fname, "rb", buffering=FILE_READ_BUFFER_SIZE)
# FileNotFoundError: [Errno 2] No such file or directory: '/proc/3282191/stat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 361, in _init
#     self.create_time()
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 714, in create_time
#     self._create_time = self._proc.create_time()
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1642, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1852, in create_time
#     ctime = float(self._parse_stat_file()['create_time'])
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1649, in wrapper
#     raise NoSuchProcess(self.pid, self._name)
# psutil.NoSuchProcess: process no longer exists (pid=3282191)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 1371, in run
#     self.function(*self.args, **self.kwargs)
#   File "/home/ryley/.local/lib/python3.10/site-packages/PyFoam/Execution/FoamThread.py", line 86, in getLinuxMem
#     me=psutil.Process(thrd.threadPid)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 332, in __init__
#     self._init(pid)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 373, in _init
#     raise NoSuchProcess(pid, msg='process PID not found')
# psutil.NoSuchProcess: process PID not found (pid=3282191)
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_0/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_0/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_0/tuner/history.json
# Did not get coefficient bounds dict for initialization, assuming coeff_bounds.json exists in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner
# Did not get coefficient default dict for initialization, assuming coeff_default.json exists in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner or is not needed
# Removing old history and suggestion files....
# Could not remove a file, it might not exist to start....
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# No history file exists at /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json, creating and registering first point
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Exception in thread Thread-43935:
# Traceback (most recent call last):
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 442, in wrapper
#     ret = self._cache[fun]
# AttributeError: 'Process' object has no attribute '_cache'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1642, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 445, in wrapper
#     return fun(self)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1684, in _parse_stat_file
#     data = bcat("%s/%s/stat" % (self._procfs_path, self.pid))
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 775, in bcat
#     return cat(fname, fallback=fallback, _open=open_binary)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 763, in cat
#     with _open(fname) as f:
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_common.py", line 727, in open_binary
#     return open(fname, "rb", buffering=FILE_READ_BUFFER_SIZE)
# FileNotFoundError: [Errno 2] No such file or directory: '/proc/3289295/stat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 361, in _init
#     self.create_time()
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 714, in create_time
#     self._create_time = self._proc.create_time()
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1642, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1852, in create_time
#     ctime = float(self._parse_stat_file()['create_time'])
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/_pslinux.py", line 1649, in wrapper
#     raise NoSuchProcess(self.pid, self._name)
# psutil.NoSuchProcess: process no longer exists (pid=3289295)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 1371, in run
#     self.function(*self.args, **self.kwargs)
#   File "/home/ryley/.local/lib/python3.10/site-packages/PyFoam/Execution/FoamThread.py", line 86, in getLinuxMem
#     me=psutil.Process(thrd.threadPid)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 332, in __init__
#     self._init(pid)
#   File "/home/ryley/.local/lib/python3.10/site-packages/psutil/__init__.py", line 373, in _init
#     raise NoSuchProcess(pid, msg='process PID not found')
# psutil.NoSuchProcess: process PID not found (pid=3289295)
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# Saving suggestion to /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/suggestion.json
#  Interrupted by the Keyboard
# Killing PID 3290643
# Registering score in /home/ryley/WDK/ML/foam/run/turbo-rans/hyperparameter_exploration/ei_xi_0.001_case_1p0_1/tuner/history.json
# KeyboardInterrupt

# %% [markdown]
# # Analysis and plotting

# %% [markdown]
# ## Comparison of loss functions

# %%
history_directory = 'foam/gridsearch/tuner/'
def load_history(historyfile):
    history = load_history_to_dict(history_directory,historyfile)
    param = [d['params']['a1'] for d in history]
    target = [d['target'] for d in history]  
    return param, target

def get_max_xy(historyfile):
    x,y = load_history(historyfile)
    ind = np.argmax(y)
    return x[ind],y[ind]

def get_percent_xy(historyfile):
    x,y = load_history(historyfile)
    y_find = max(y)-abs(max(y))*0.025
    difference_array = abs(np.asarray(y) - y_find)
    ind = np.argmin(difference_array)
    return x[ind],y[ind]

fig, ax1 = plt.subplots(constrained_layout=True)
ax2 = ax1.twinx()

ax1.plot(load_history('history_foam_mse_U_componentwise_2Dxy.json')[0],
         load_history('history_foam_mse_U_componentwise_2Dxy.json')[1],
         'k--',
         label='MSE_U_componentwise')

ax1.scatter(x = get_max_xy('history_foam_mse_U_componentwise_2Dxy.json')[0],
            y = get_max_xy('history_foam_mse_U_componentwise_2Dxy.json')[1],
            c='k')

ax1.scatter(x = get_percent_xy('history_foam_mse_U_componentwise_2Dxy.json')[0],
            y = get_percent_xy('history_foam_mse_U_componentwise_2Dxy.json')[1],
            facecolors='none', edgecolors='k')

ax1.plot(load_history('history_foam_mse_U_magnitude_2Dxy.json')[0],
         load_history('history_foam_mse_U_magnitude_2Dxy.json')[1],
         'b--',
         label='MSE_U_mag')
ax1.scatter(x = get_max_xy('history_foam_mse_U_magnitude_2Dxy.json')[0],
            y = get_max_xy('history_foam_mse_U_magnitude_2Dxy.json')[1],
            c='b')
ax1.scatter(x = get_percent_xy('history_foam_mse_U_magnitude_2Dxy.json')[0],
            y = get_percent_xy('history_foam_mse_U_magnitude_2Dxy.json')[1],
            facecolors='none', edgecolors='b')

ax1.plot(load_history('history_foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean.json')[0],
         load_history('history_foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean.json')[1],
         label='MSE_U_mag_coef',c='b')
ax1.scatter(x = get_max_xy('history_foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean.json')[0],
            y = get_max_xy('history_foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean.json')[1],
            c='b')

ax2.plot(load_history('history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')[0],
         load_history('history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')[1],
         'brown',linestyle='dashed',
         label='MAPE_U_mag_k')

ax2.scatter(x = get_max_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')[0],
            y = get_max_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')[1],
            c='brown')
ax2.scatter(x = get_percent_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')[0],
            y = get_percent_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')[1],
            facecolors='none', edgecolors='brown')

ax2.plot(load_history('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean.json')[0],
         load_history('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean.json')[1],
         'orange',
         label=r'MAPE_U_mag_k_coef, $\lambda$ =1')
ax2.scatter(x = get_max_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean.json')[0],
            y = get_max_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean.json')[1],
            c='orange')

ax2.plot(load_history('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p5.json')[0],
         load_history('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p5.json')[1],
         'darkgoldenrod',
         label=r'MAPE_U_mag_k_coef, $\lambda$ =0.5')
ax2.scatter(x = get_max_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p5.json')[0],
            y = get_max_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p5.json')[1],
            c='darkgoldenrod')

ax2.plot(load_history('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p25.json')[0],
         load_history('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p25.json')[1],
         'red',
         label=r'MAPE_U_mag_k_coef, $\lambda$ =0.25')

ax2.scatter(x = get_max_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p25.json')[0],
            y = get_max_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p25.json')[1],
            c='red')

ax1.set_ylim([-0.000040,0])
ax2.set_ylim([-2,0])
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=4)
ax1.set_xlabel(r'$a_1$')
ax1.set_ylabel('MSE loss functions')
ax2.set_ylabel('MAPE loss functions')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 23>()
#      20 fig, ax1 = plt.subplots(constrained_layout=True)
#      21 ax2 = ax1.twinx()
# ---> 23 ax1.plot(load_history('history_foam_mse_U_componentwise_2Dxy.json')[0],
#      24          load_history('history_foam_mse_U_componentwise_2Dxy.json')[1],
#      25          'k--',
#      26          label='MSE_U_componentwise')
#      28 ax1.scatter(x = get_max_xy('history_foam_mse_U_componentwise_2Dxy.json')[0],
#      29             y = get_max_xy('history_foam_mse_U_componentwise_2Dxy.json')[1],
#      30             c='k')
#      32 ax1.scatter(x = get_percent_xy('history_foam_mse_U_componentwise_2Dxy.json')[0],
#      33             y = get_percent_xy('history_foam_mse_U_componentwise_2Dxy.json')[1],
#      34             facecolors='none', edgecolors='k')
#
# Input In [17], in load_history(historyfile)
#       2 def load_history(historyfile):
# ----> 3     history = load_history_to_dict(history_directory,historyfile)
#       4     param = [d['params']['a1'] for d in history]
#       5     target = [d['target'] for d in history]
#
# NameError: name 'load_history_to_dict' is not defined

# %% [markdown]
# ## Number of iterations

# %%
def load_history(historyfile,history_directory='foam/gridsearch_a1_phll/tuner/'):
    history = load_history_to_dict(history_directory,historyfile)
    param = [d['params']['a1'] for d in history]
    target = [d['target'] for d in history]  
    
    return param, target
def get_max_xy(historyfile):
    x,y = load_history(historyfile)
    ind = np.argmax(y)
    return x[ind],y[ind]

def get_percent_xy(historyfile):
    x,y = load_history(historyfile)
    y_find = max(y)-abs(max(y))*0.025
    difference_array = abs(np.asarray(y) - y_find)
    ind = np.argmin(difference_array)
    return x[ind],y[ind]

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12,4), constrained_layout=True)
ax1 = axs[0]
ax2 = axs[1]

ax1.plot(load_history('history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')[0],
         load_history('history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')[1],
         'brown',linestyle='dashed',
         label='MAPE_U_mag_k')
ax1.scatter(x = get_max_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')[0],
            y = get_max_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')[1],
            c='brown')
ax1.scatter(x = get_percent_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')[0],
            y = get_percent_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')[1],
            facecolors='none', edgecolors='brown')


ax2.plot(load_history('history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')[0],
         load_history('history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')[1],
         'brown',linestyle='dashed',
         label='MAPE_U_mag_k')

ax2.scatter(x = get_max_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')[0],
            y = get_max_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')[1],
            c='brown')
ax2.scatter(x = get_percent_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')[0],
            y = get_percent_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')[1],
            facecolors='none', edgecolors='brown')


ax1.plot(load_history('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p5.json')[0],
         load_history('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p5.json')[1],
         'darkgoldenrod',
         label=r'MAPE_U_mag_k_coef, $\lambda$ =0.5')
ax1.scatter(x = get_max_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p5.json')[0],
            y = get_max_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p5.json')[1],
            c='darkgoldenrod')

ax1.scatter(x = get_max_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p5.json')[0],
            y = get_max_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p5.json')[1],
            c='darkgoldenrod')
ax1.scatter(x = load_history('history.json',history_directory='foam/bayesian_a1_phll/case_1p0_lda0p5_10iter/tuner')[0],
            y = load_history('history.json',history_directory='foam/bayesian_a1_phll/case_1p0_lda0p5_10iter/tuner')[1],
            facecolors='k', edgecolors='k',s=20)


ax2.plot(load_history('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p25.json')[0],
         load_history('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p25.json')[1],
         'red',
         label=r'MAPE_U_mag_k_coef, $\lambda$ =0.25')
ax2.scatter(x = get_max_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p25.json')[0],
            y = get_max_xy('history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p25.json')[1],
            c='red')

ax2.scatter(x = load_history('history.json',history_directory='foam/bayesian_a1_phll/case_1p0_lda0p25_10iter/tuner')[0],
            y = load_history('history.json',history_directory='foam/bayesian_a1_phll/case_1p0_lda0p25_10iter/tuner')[1],
            facecolors='k', edgecolors='k',s=20)


ax2.set_ylim([-2,-.5])
ax2.set_ylim([-2,-.5])

lines, labels = ax1.get_legend_handles_labels()
ax1.set_xlabel(r'$a_1$')
ax1.set_ylabel('MAPE" loss functions')
# Out:
# Text(0, 0.5, 'MAPE" loss functions')

# %% [markdown]
# ##

# %% [markdown]
# # Old code

# %%
param_relUkc,target_relUkc = load_history('history_relUkc.json')
param_relUkc,target_relUkc = load_history('history_relUkc.json')

# %%
plt.scatter(param_relUk,target_relUk,label='relUk')
plt.scatter(param_relUkc,target_relUkc,label='relUkc')
plt.scatter(param_relUkc05,target_relUkc05,label='relUkc05')

#print(target_comp[0:5])
#print(target_mag[0:5])
#print(target_mag)

# %%
def print_bare_goals_at_selected(ind):
    print(f'Point sel: {param_comp[ind]}')
    print(f'relUk max: {target_relUk[ind]}') 
    print(f'error mag: {target_mag[ind]}') 

print('relUk max:')
print_bare_goals_at_selected(np.argmax(target_relUk))

print('Error max max:')
print_bare_goals_at_selected(np.argmax(target_mag))

print('rel1:')
print_bare_goals_at_selected(np.argmax(target_rel1))

print('rel2:')
print_bare_goals_at_selected(np.argmax(target_rel2))

print('relUkc:')
print_bare_goals_at_selected(np.argmax(target_relUkc))

print('relUkc05')
print_bare_goals_at_selected(np.argmax(target_relUkc05))
# Out:
# relUk max:
# Point sel: 0.5239
# relUk max: -0.583446843127357
# error mag: -1.9043332771432456e-06
# Error max max:
# Point sel: 0.487
# relUk max: -0.5850325132177929
# error mag: -1.9029594592617798e-06
# rel1:
# Point sel: 0.387
# relUk max: -0.6201985266448174
# error mag: -2.0137207480104776e-06
# rel2:
# Point sel: 0.3761
# relUk max: -0.634919507648456
# error mag: -2.0907158259925327e-06
# relUkc:
# Point sel: 0.3761
# relUk max: -0.634919507648456
# error mag: -2.0907158259925327e-06
# relUkc05
# Point sel: 0.3891
# relUk max: -0.6182589673434529
# error mag: -2.004407892737836e-06

# %%
import matplotlib.pyplot as plt

plt.scatter(param_comp,target_comp,label='comp')
plt.scatter(param_mag,target_mag,label='mag')
plt.scatter(param_rel1,target_rel1,label='rel1')
plt.scatter(param_rel2,target_rel2,label='rel2')

#print(target_comp[0:5])
#print(target_mag[0:5])
#print(target_mag)

# %%
import pprint
pprint.pprint(history)
# Out:
# [{'datetime': {'datetime': '2022-06-02 19:11:22', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.15},
#   'target': 2.466547322840756e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:22', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1522},
#   'target': 2.3300893836578992e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:23', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1543},
#   'target': 2.7916139904196577e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:23', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1565},
#   'target': 2.7443275276943687e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:23', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1587},
#   'target': 2.8174783522166515e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:24', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1609},
#   'target': 2.5641766501330933e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:24', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.163},
#   'target': 2.2678564580158122e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:25', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1652},
#   'target': 2.271709342161399e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:25', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1674},
#   'target': 2.2267183877876428e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:26', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1696},
#   'target': 2.2551866736496256e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:26', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1717},
#   'target': 2.5738087371542577e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:26', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1739},
#   'target': 2.2122614537471908e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:27', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1761},
#   'target': 2.2929404699454456e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:27', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1783},
#   'target': 2.4804685942802594e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:28', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1804},
#   'target': 2.2013109690833132e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:28', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1826},
#   'target': 2.1403511868037422e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:29', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1848},
#   'target': 2.4112449474416364e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:29', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.187},
#   'target': 2.1095186859420177e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:30', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1891},
#   'target': 2.3117833599094296e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:30', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1913},
#   'target': 2.282489506511556e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:30', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1935},
#   'target': 2.173854193134433e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:31', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1957},
#   'target': 2.153291558956269e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:31', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.1978},
#   'target': 2.1834510905050167e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:32', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2},
#   'target': 2.1709919064535812e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:32', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2022},
#   'target': 2.0848188101293508e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:33', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2043},
#   'target': 2.0709934912295565e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:33', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2065},
#   'target': 2.046528576072901e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:34', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2087},
#   'target': 2.0197743203118706e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:34', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2109},
#   'target': 1.9929465990990476e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:34', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.213},
#   'target': 1.9679705789376706e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:35', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2152},
#   'target': 1.9416393365838385e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:35', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2174},
#   'target': 1.9119914952234708e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:36', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2196},
#   'target': 1.8755051500527248e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:36', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2217},
#   'target': 1.8347475708634843e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:37', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2239},
#   'target': 1.7876504992742792e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:37', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2261},
#   'target': 1.7370812658854962e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:38', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2283},
#   'target': 1.6835908369304764e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:38', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2304},
#   'target': 1.630100709181196e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:38', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2326},
#   'target': 1.5726196455547727e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:39', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2348},
#   'target': 1.515476179841971e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:39', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.237},
#   'target': 1.4601004589611866e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:40', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2391},
#   'target': 1.4091822877515875e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:40', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2413},
#   'target': 1.357831882193239e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:41', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2435},
#   'target': 1.3083694572822546e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:41', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2457},
#   'target': 1.2606230938478465e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:42', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2478},
#   'target': 1.2164294340627595e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:42', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.25},
#   'target': 1.171517391163839e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:42', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2522},
#   'target': 1.1279056531271758e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:43', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2543},
#   'target': 1.0874458369400083e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:43', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2565},
#   'target': 1.046198308439995e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:44', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2587},
#   'target': 1.0060630800797957e-05},
#  {'datetime': {'datetime': '2022-06-02 19:11:44', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2609},
#   'target': 9.671309182319573e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:45', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.263},
#   'target': 9.31098075793625e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:45', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2652},
#   'target': 8.946713816463287e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:45', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2674},
#   'target': 8.593152952529178e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:46', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2696},
#   'target': 8.249619575245082e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:46', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2717},
#   'target': 7.931523605597783e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:47', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2739},
#   'target': 7.6088167100492894e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:47', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2761},
#   'target': 7.297986780115533e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:48', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2783},
#   'target': 7.001791857406953e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:48', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2804},
#   'target': 6.730879249765069e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:49', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2826},
#   'target': 6.457199680622256e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:49', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2848},
#   'target': 6.19343659609371e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:49', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.287},
#   'target': 5.939029064980952e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:50', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2891},
#   'target': 5.703349696434445e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:50', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2913},
#   'target': 5.464079749370201e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:51', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2935},
#   'target': 5.231935195876849e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:51', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2957},
#   'target': 5.0068700597132214e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:52', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.2978},
#   'target': 4.797155271686069e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:52', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3},
#   'target': 4.580943161325829e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:53', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3022},
#   'target': 4.359949692425264e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:53', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3043},
#   'target': 4.164000054545962e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:53', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3065},
#   'target': 3.953949646593409e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:54', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3087},
#   'target': 3.765672172632843e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:54', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3109},
#   'target': 3.6826735521192077e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:55', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.313},
#   'target': 3.543768873121936e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:55', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3152},
#   'target': 3.359396832850341e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:56', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3174},
#   'target': 3.1933503654009854e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:56', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3196},
#   'target': 3.039579619273804e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:56', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3217},
#   'target': 2.883218796613714e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:57', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3239},
#   'target': 2.7444925822763357e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:57', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3261},
#   'target': 2.614398357992877e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:58', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3283},
#   'target': 2.4903161500903996e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:58', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3304},
#   'target': 2.377055522182711e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:59', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3326},
#   'target': 2.263530029373746e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:59', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3348},
#   'target': 2.1552786978339108e-06},
#  {'datetime': {'datetime': '2022-06-02 19:11:59', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.337},
#   'target': 2.052536190961917e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:00', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3391},
#   'target': 1.959232995723142e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:00', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3413},
#   'target': 1.8666364883997609e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:01', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3435},
#   'target': 1.7789871602645274e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:01', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3457},
#   'target': 1.6963938676954914e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:02', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3478},
#   'target': 1.622211456843074e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:02', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.35},
#   'target': 1.5492646228527304e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:02', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3522},
#   'target': 1.4816068932491192e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:03', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3543},
#   'target': 1.4215915642944072e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:03', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3565},
#   'target': 1.3636769184691335e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:04', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3587},
#   'target': 1.3114820287751223e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:04', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3609},
#   'target': 1.265376662191708e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:05', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.363},
#   'target': 1.2270170006768203e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:05', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3652},
#   'target': 1.1934386912089759e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:05', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3674},
#   'target': 1.1676661768442102e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:06', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3696},
#   'target': 1.149135810964834e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:06', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3717},
#   'target': 1.1348547462387384e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:07', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3739},
#   'target': 1.1210044811516784e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:07', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3761},
#   'target': 1.1084938518416194e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:08', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3783},
#   'target': 1.0971006050369387e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:08', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3804},
#   'target': 1.087654494935051e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:09', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3826},
#   'target': 1.0789226052698333e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:09', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3848},
#   'target': 1.0712099228542488e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:09', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.387},
#   'target': 1.0646024017598852e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:10', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3891},
#   'target': 1.0593192321743573e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:10', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3913},
#   'target': 1.0545448658783093e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:11', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3935},
#   'target': 1.050225484810875e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:11', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3957},
#   'target': 1.0461532445871415e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:12', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.3978},
#   'target': 1.0425360536992123e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:12', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4},
#   'target': 1.0389903966048605e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:13', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4022},
#   'target': 1.0356566744493548e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:13', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4043},
#   'target': 1.0327074534982734e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:13', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4065},
#   'target': 1.0298503608455509e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:14', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4087},
#   'target': 1.0271712883609338e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:14', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4109},
#   'target': 1.0247461868865065e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:15', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.413},
#   'target': 1.0225854826320596e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:15', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4152},
#   'target': 1.0204904035209831e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:16', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4174},
#   'target': 1.0185805048093782e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:16', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4196},
#   'target': 1.016811314448044e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:16', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4217},
#   'target': 1.0152437889671457e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:17', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4239},
#   'target': 1.0137195718975308e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:17', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4261},
#   'target': 1.0122917667687487e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:18', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4283},
#   'target': 1.0110238892225142e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:18', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4304},
#   'target': 1.0098897578186964e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:19', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4326},
#   'target': 1.0088130282097688e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:19', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4348},
#   'target': 1.007802605013826e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:20', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.437},
#   'target': 1.0068688234128336e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:20', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4391},
#   'target': 1.0060677705512263e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:20', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4413},
#   'target': 1.0052820475993814e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:21', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4435},
#   'target': 1.0045868968886265e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:21', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4457},
#   'target': 1.0039221710628603e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:22', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4478},
#   'target': 1.0033301925704507e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:22', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.45},
#   'target': 1.002759839436494e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:23', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4522},
#   'target': 1.0022812969089037e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:23', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4543},
#   'target': 1.001835533113702e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:24', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4565},
#   'target': 1.001435819283385e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:24', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4587},
#   'target': 1.0010685307541734e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:24', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4609},
#   'target': 1.0007332931327017e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:25', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.463},
#   'target': 1.0004122474463824e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:25', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4652},
#   'target': 1.0001685726871e-06},
#  {'datetime': {'datetime': '2022-06-02 19:12:26', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4674},
#   'target': 9.999211015194634e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:26', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4696},
#   'target': 9.997438206191532e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:27', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4717},
#   'target': 9.995775747160392e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:27', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4739},
#   'target': 9.993778995146012e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:27', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4761},
#   'target': 9.992343766779413e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:28', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4783},
#   'target': 9.991177225696172e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:28', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4804},
#   'target': 9.990277976090273e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:29', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4826},
#   'target': 9.98938834687183e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:29', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4848},
#   'target': 9.988560749137071e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:30', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.487},
#   'target': 9.987595366529443e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:30', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4891},
#   'target': 9.987155194483076e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:31', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4913},
#   'target': 9.986911065470507e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:31', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4935},
#   'target': 9.986521402431172e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:31', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4957},
#   'target': 9.986544796148803e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:32', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.4978},
#   'target': 9.986578663863966e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:32', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5},
#   'target': 9.986738743249629e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:33', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5022},
#   'target': 9.986976820411337e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:33', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5043},
#   'target': 9.98725463387967e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:34', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5065},
#   'target': 9.987733951520835e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:34', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5087},
#   'target': 9.98825500076397e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:35', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5109},
#   'target': 9.988604844800298e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:35', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.513},
#   'target': 9.989195788324798e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:35', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5152},
#   'target': 9.989580885611275e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:36', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5174},
#   'target': 9.989572291971948e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:36', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5196},
#   'target': 9.989825313489354e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:37', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5217},
#   'target': 9.990051272679537e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:37', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5239},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:38', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5261},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:38', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5283},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:38', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5304},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:39', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5326},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:39', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5348},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:40', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.537},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:40', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5391},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:41', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5413},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:41', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5435},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:42', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5457},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:42', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5478},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:42', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.55},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:43', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5522},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:43', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5543},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:44', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5565},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:44', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5587},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:45', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5609},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:45', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.563},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:45', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5652},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:46', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5674},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:46', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5696},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:47', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5717},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:47', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5739},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:48', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5761},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:48', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5783},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:49', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5804},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:49', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5826},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:49', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5848},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:50', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.587},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:50', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5891},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:51', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5913},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:51', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5935},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:52', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5957},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:52', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.5978},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:53', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:53', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6022},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:53', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6043},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:54', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6065},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:54', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6087},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:55', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6109},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:55', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.613},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:56', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6152},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:56', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6174},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:57', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6196},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:57', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6217},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:57', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6239},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:58', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6261},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:58', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6283},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:59', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6304},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:12:59', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6326},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:00', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6348},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:00', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.637},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:01', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6391},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:01', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6413},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:01', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6435},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:02', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6457},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:02', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6478},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:03', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.65},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:03', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6522},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:04', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6543},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:04', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6565},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:05', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6587},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:05', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6609},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:05', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.663},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:06', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6652},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:06', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6674},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:07', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6696},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:07', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6717},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:08', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6739},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:08', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6761},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:09', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6783},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:09', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6804},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:10', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6826},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:10', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6848},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:10', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.687},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:11', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6891},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:11', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6913},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:12', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6935},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:12', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6957},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:13', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.6978},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:13', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:14', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7022},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:14', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7043},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:15', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7065},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:15', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7087},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:16', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7109},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:16', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.713},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:17', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7152},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:17', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7174},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:17', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7196},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:18', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7217},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:18', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7239},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:19', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7261},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:19', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7283},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:20', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7304},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:20', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7326},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:21', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7348},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:21', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.737},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:22', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7391},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:22', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7413},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:23', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7435},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:23', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7457},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:23', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7478},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:24', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.75},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:24', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7522},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:25', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7543},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:25', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7565},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:26', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7587},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:26', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7609},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:27', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.763},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:27', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7652},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:28', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7674},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:28', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7696},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:28', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7717},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:29', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7739},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:29', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7761},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:30', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7783},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:30', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7804},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:31', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7826},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:31', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7848},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:32', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.787},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:32', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7891},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:33', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7913},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:33', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7935},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:34', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7957},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:34', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.7978},
#   'target': 9.990086678332635e-07},
#  {'datetime': {'datetime': '2022-06-02 19:13:34', 'delta': 0.0, 'elapsed': 0.0},
#   'params': {'a1': 0.8},
#   'target': 9.990086678332635e-07}]

# %%
print(param)
# Out:
# [0.15, 0.1522, 0.1543, 0.1565, 0.1587, 0.1609, 0.163, 0.1652, 0.1674, 0.1696, 0.1717, 0.1739, 0.1761, 0.1783, 0.1804, 0.1826, 0.1848, 0.187, 0.1891, 0.1913, 0.1935, 0.1957, 0.1978, 0.2, 0.2022, 0.2043, 0.2065, 0.2087, 0.2109, 0.213, 0.2152, 0.2174, 0.2196, 0.2217, 0.2239, 0.2261, 0.2283, 0.2304, 0.2326, 0.2348, 0.237, 0.2391, 0.2413, 0.2435, 0.2457, 0.2478, 0.25, 0.2522, 0.2543, 0.2565, 0.2587, 0.2609, 0.263, 0.2652, 0.2674, 0.2696, 0.2717, 0.2739, 0.2761, 0.2783, 0.2804, 0.2826, 0.2848, 0.287, 0.2891, 0.2913, 0.2935, 0.2957, 0.2978, 0.3, 0.3022, 0.3043, 0.3065, 0.3087, 0.3109, 0.313, 0.3152, 0.3174, 0.3196, 0.3217, 0.3239, 0.3261, 0.3283, 0.3304, 0.3326, 0.3348, 0.337, 0.3391, 0.3413, 0.3435, 0.3457, 0.3478, 0.35, 0.3522, 0.3543, 0.3565, 0.3587, 0.3609, 0.363, 0.3652, 0.3674, 0.3696, 0.3717, 0.3739, 0.3761, 0.3783, 0.3804, 0.3826, 0.3848, 0.387, 0.3891, 0.3913, 0.3935, 0.3957, 0.3978, 0.4, 0.4022, 0.4043, 0.4065, 0.4087, 0.4109, 0.413, 0.4152, 0.4174, 0.4196, 0.4217, 0.4239, 0.4261, 0.4283, 0.4304, 0.4326, 0.4348, 0.437, 0.4391, 0.4413, 0.4435, 0.4457, 0.4478, 0.45, 0.4522, 0.4543, 0.4565, 0.4587, 0.4609, 0.463, 0.4652, 0.4674, 0.4696, 0.4717, 0.4739, 0.4761, 0.4783, 0.4804, 0.4826, 0.4848, 0.487, 0.4891, 0.4913, 0.4935, 0.4957, 0.4978, 0.5, 0.5022, 0.5043, 0.5065, 0.5087, 0.5109, 0.513, 0.5152, 0.5174, 0.5196, 0.5217, 0.5239, 0.5261, 0.5283, 0.5304, 0.5326, 0.5348, 0.537, 0.5391, 0.5413, 0.5435, 0.5457, 0.5478, 0.55, 0.5522, 0.5543, 0.5565, 0.5587, 0.5609, 0.563, 0.5652, 0.5674, 0.5696, 0.5717, 0.5739, 0.5761, 0.5783, 0.5804, 0.5826, 0.5848, 0.587, 0.5891, 0.5913, 0.5935, 0.5957, 0.5978, 0.6, 0.6022, 0.6043, 0.6065, 0.6087, 0.6109, 0.613, 0.6152, 0.6174, 0.6196, 0.6217, 0.6239, 0.6261, 0.6283, 0.6304, 0.6326, 0.6348, 0.637, 0.6391, 0.6413, 0.6435, 0.6457, 0.6478, 0.65, 0.6522, 0.6543, 0.6565, 0.6587, 0.6609, 0.663, 0.6652, 0.6674, 0.6696, 0.6717, 0.6739, 0.6761, 0.6783, 0.6804, 0.6826, 0.6848, 0.687, 0.6891, 0.6913, 0.6935, 0.6957, 0.6978, 0.7, 0.7022, 0.7043, 0.7065, 0.7087, 0.7109, 0.713, 0.7152, 0.7174, 0.7196, 0.7217, 0.7239, 0.7261, 0.7283, 0.7304, 0.7326, 0.7348, 0.737, 0.7391, 0.7413, 0.7435, 0.7457, 0.7478, 0.75, 0.7522, 0.7543, 0.7565, 0.7587, 0.7609, 0.763, 0.7652, 0.7674, 0.7696, 0.7717, 0.7739, 0.7761, 0.7783, 0.7804, 0.7826, 0.7848, 0.787, 0.7891, 0.7913, 0.7935, 0.7957, 0.7978, 0.8]

# %%
# Calculate errors loop

ref_df = pd.read_csv('foam/gridsearch_a1_phll/tuner/refdata.csv')
initialize(directory = history_directory,
           coeff_bounds = {'a1':[min(a1_vec),max(a1_vec)]},
           coeff_default = {'a1': 0.31},
           restart = True)

for a1 in a1_vec:
    casedir = f'foam/gridsearch_a1_phll/case_1p0_a1_{a1}'
    foamLoss = computeFoamFieldLossFunc(foamdir=casedir,
                                        ref_df=ref_df,
                                        interp_method='nearest')
    search_point = {'a1': a1}
    write_suggestion(directory = history_directory, suggestion = search_point)
    last_time = get_endtime(case=casedir)
    
    save_dict = {
        'parmas': search_point,
        'foam_mse_U_componentwise_2Dxy': -foamLoss.foam_mse_U_componentwise_2Dxy(foamtime=last_time),
        'foam_mse_U_magnitude_2Dxy': -foamLoss.foam_mse_U_magnitude_2Dxy(foamtime=last_time),
        'foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean': -foamLoss.foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory)),
        'foam_multi_mape_U_magnitude_2Dxy_relcoeff_mean': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory)),
        'foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory)),
        'foam_multi_mape_U_magnitude_2Dxy_mape_k': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k(foamtime=last_time),
        'foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda_0p25': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory),lda=0.25),
        'foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda_0p5': -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                            coeff_dict=search_point,
                                                            coeff_default=load_coeff_default(directory=history_directory),lda=0.t5)
    }
    
    write_json(history_directory, save_dict, 'lossfuncs_gridsearch.json')
    score1 = -foamLoss.foam_mse_U_componentwise_2Dxy(foamtime=last_time)
    score2 = -foamLoss.foam_mse_U_magnitude_2Dxy(foamtime=last_time)
    score3 = -foamLoss.foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score4 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score5 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score6 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k(foamtime=last_time)
    register_score(score=score1, 
                   directory = history_directory)
os.system(f"mv {os.path.join(history_directory,'history.json')} {os.path.join(history_directory,'history_foam_mse_U_componentwise_2Dxy.json')}")

for a1 in a1_vec:
    casedir = f'foam/gridsearch_a1_phll/case_1p0_a1_{a1}'
    foamLoss = computeFoamFieldLossFunc(foamdir=casedir,
                                        ref_df=ref_df,
                                        interp_method='nearest')
    search_point = {'a1': a1}
    write_suggestion(directory = history_directory, suggestion = search_point)
    last_time = get_endtime(case=casedir)
    score1 = -foamLoss.foam_mse_U_componentwise_2Dxy(foamtime=last_time)
    score2 = -foamLoss.foam_mse_U_magnitude_2Dxy(foamtime=last_time)
    score3 = -foamLoss.foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score4 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score5 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score6 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k(foamtime=last_time)
    register_score(score=score2, 
                   directory = history_directory)
os.system(f"mv {os.path.join(history_directory,'history.json')} {os.path.join(history_directory,'history_foam_mse_U_magnitude_2Dxy.json')}")

for a1 in a1_vec:
    casedir = f'foam/gridsearch_a1_phll/case_1p0_a1_{a1}'
    foamLoss = computeFoamFieldLossFunc(foamdir=casedir,
                                        ref_df=ref_df,
                                        interp_method='nearest')
    search_point = {'a1': a1}
    write_suggestion(directory = history_directory, suggestion = search_point)
    last_time = get_endtime(case=casedir)
    score1 = -foamLoss.foam_mse_U_componentwise_2Dxy(foamtime=last_time)
    score2 = -foamLoss.foam_mse_U_magnitude_2Dxy(foamtime=last_time)
    score3 = -foamLoss.foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score4 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score5 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score6 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k(foamtime=last_time)
    register_score(score=score3, 
                   directory = history_directory)
os.system(f"mv {os.path.join(history_directory,'history.json')} {os.path.join(history_directory,'history_foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean.json')}")

for a1 in a1_vec:
    casedir = f'foam/gridsearch_a1_phll/case_1p0_a1_{a1}'
    foamLoss = computeFoamFieldLossFunc(foamdir=casedir,
                                        ref_df=ref_df,
                                        interp_method='nearest')
    search_point = {'a1': a1}
    write_suggestion(directory = history_directory, suggestion = search_point)
    last_time = get_endtime(case=casedir)
    score1 = -foamLoss.foam_mse_U_componentwise_2Dxy(foamtime=last_time)
    score2 = -foamLoss.foam_mse_U_magnitude_2Dxy(foamtime=last_time)
    score3 = -foamLoss.foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score4 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score5 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score6 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k(foamtime=last_time)
    register_score(score=score4, 
                   directory = history_directory)
os.system(f"mv {os.path.join(history_directory,'history.json')} {os.path.join(history_directory,'history_foam_multi_mape_U_magnitude_2Dxy_relcoeff_mean.json')}")

for a1 in a1_vec:
    casedir = f'foam/gridsearch_a1_phll/case_1p0_a1_{a1}'
    foamLoss = computeFoamFieldLossFunc(foamdir=casedir,
                                        ref_df=ref_df,
                                        interp_method='nearest')
    search_point = {'a1': a1}
    write_suggestion(directory = history_directory, suggestion = search_point)
    last_time = get_endtime(case=casedir)
    score1 = -foamLoss.foam_mse_U_componentwise_2Dxy(foamtime=last_time)
    score2 = -foamLoss.foam_mse_U_magnitude_2Dxy(foamtime=last_time)
    score3 = -foamLoss.foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score4 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score5 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score6 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k(foamtime=last_time)
    register_score(score=score5, 
                   directory = history_directory)
os.system(f"mv {os.path.join(history_directory,'history.json')} {os.path.join(history_directory,'history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean.json')}")

for a1 in a1_vec:
    casedir = f'foam/gridsearch_a1_phll/case_1p0_a1_{a1}'
    foamLoss = computeFoamFieldLossFunc(foamdir=casedir,
                                        ref_df=ref_df,
                                        interp_method='nearest')
    search_point = {'a1': a1}
    write_suggestion(directory = history_directory, suggestion = search_point)
    last_time = get_endtime(case=casedir)
    score1 = -foamLoss.foam_mse_U_componentwise_2Dxy(foamtime=last_time)
    score2 = -foamLoss.foam_mse_U_magnitude_2Dxy(foamtime=last_time)
    score3 = -foamLoss.foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score4 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score5 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score6 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k(foamtime=last_time)
    register_score(score=score6, 
                   directory = history_directory)
os.system(f"mv {os.path.join(history_directory,'history.json')} {os.path.join(history_directory,'history_foam_multi_mape_U_magnitude_2Dxy_mape_k.json')}")
# Out:
# Saving coeff_bounds to foam/gridsearch_a1_phll/tuner/coeff_bounds.json
# Saving coeff_default to foam/gridsearch_a1_phll/tuner/coeff_default.json
# Removing old history and suggestion files....
# Could not remove a file, it might not exist to start....
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# No history file exists at foam/gridsearch_a1_phll/tuner/history.json, creating and registering first point
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# No history file exists at foam/gridsearch_a1_phll/tuner/history.json, creating and registering first point
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# ...
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# 0

# %%
for a1 in a1_vec:
    casedir = f'foam/gridsearch_a1_phll/case_1p0_a1_{a1}'
    foamLoss = computeFoamFieldLossFunc(foamdir=casedir,
                                        ref_df=ref_df,
                                        interp_method='nearest')
    search_point = {'a1': a1}
    write_suggestion(directory = history_directory, suggestion = search_point)
    last_time = get_endtime(case=casedir)
    score1 = -foamLoss.foam_mse_U_componentwise_2Dxy(foamtime=last_time)
    score2 = -foamLoss.foam_mse_U_magnitude_2Dxy(foamtime=last_time)
    score3 = -foamLoss.foam_multi_mse_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score4 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score5 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory))
    score6 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k(foamtime=last_time)
    score8 = -foamLoss.foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean(foamtime=last_time,
                                                                    coeff_dict=search_point,
                                                                    coeff_default=load_coeff_default(directory=history_directory),lda=0.25)
    register_score(score=score8, 
                   directory = history_directory)
os.system(f"mv {os.path.join(history_directory,'history.json')} {os.path.join(history_directory,'history_foam_multi_mape_U_magnitude_2Dxy_mape_k_relcoeff_mean_lda0p25.json')}")
# Out:
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# No history file exists at foam/gridsearch_a1_phll/tuner/history.json, creating and registering first point
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# Saving suggestion to foam/gridsearch_a1_phll/tuner/suggestion.json
# Registering score in foam/gridsearch_a1_phll/tuner/history.json
# 0
