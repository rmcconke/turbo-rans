# %%
import numpy as np
import os
import fileinput
import sys
import pandas as pd
import matplotlib.pyplot as plt

from utilities.foam_automation.caserunner import run_until_convergence, get_endtime
from utilities.foam_automation.computeFoamLossFunc import computeFoamFieldLossFunc
from utilities.foam_automation.set_foam_coeff import set_foam_coef

from utilities.json_io import write_suggestion, write_json, load_coeff_default, load_coeff_bounds, load_history_loss_log, load_suggestion

from utilities.control import initialize
from update_history import register_score
from suggest_coeffs import suggest
import random

# %%
a1_vec = np.around(np.linspace(0.15,0.8,300),4)
betastar_vec = np.around(np.linspace(0.045,0.25,100),4)
history_directory = '/home/ryley/WDK/ML/foam/run/turbo-rans/gridsearch/tuner'

a1_combined, betastar_combined = np.meshgrid(np.around(np.linspace(0.24,0.6,30),4),
                                             np.around(np.linspace(0.045,0.14,30),4))
a1_combined = a1_combined.flatten()
betastar_combined = betastar_combined.flatten()

# %%
# Run simulation loop    
for betastar in betastar_vec:
    casedir = f'foam/gridsearch/betaStar_phll/case_1p0_betastar_{betastar}'
    os.system(f'cp -r foam/gridsearch/betaStar_phll/case_1p0_template {casedir}')
    search_point = {'betaStar': betastar}
    write_suggestion(directory = history_directory, suggestion = search_point)
    set_foam_coef(casedir,search_point)
    #Uncomment to run
    #last_time = run_until_convergence(case = casedir, n_proc = 16)
# Out:
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json

# %%
# Run simulation loop (already run)
for a1 in a1_vec:
    casedir = f'foam/gridsearch_a1_phll/case_1p0_a1_{a1}'
    os.system(f'cp -r foam/gridsearch_a1_phll/case_1p0_template {casedir}')
    search_point = {'a1': a1}
    write_suggestion(directory = history_directory, suggestion = search_point)
    set_foam_coef(casedir,search_point)
    #Uncomment to run
    #last_time = run_until_convergence(case = casedir, n_proc = 16)

# %%
for a1, betastar in zip(a1_combined, betastar_combined):
    casedir = f'foam/gridsearch/a1_betaStar_phll/case_1p0_a1_{a1}_betaStar_{betastar}'
    os.system(f'cp -r foam/gridsearch/a1_betaStar_phll/case_1p0_template {casedir}')
    search_point = {'a1': a1,
                    'betaStar': betastar}
    write_suggestion(directory = history_directory, suggestion = search_point)
    set_foam_coef(casedir,search_point)
    #Uncomment to run
    #last_time = run_until_convergence(case = casedir, n_proc = 16)
# Out:
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Exception in thread Thread-5169:
# Traceback (most recent call last):
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_common.py", line 442, in wrapper
#     ret = self._cache[fun]
# AttributeError: _cache
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_pslinux.py", line 1642, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_common.py", line 445, in wrapper
#     return fun(self)
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_pslinux.py", line 1684, in _parse_stat_file
#     data = bcat("%s/%s/stat" % (self._procfs_path, self.pid))
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_common.py", line 775, in bcat
#     return cat(fname, fallback=fallback, _open=open_binary)
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_common.py", line 763, in cat
#     with _open(fname) as f:
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_common.py", line 727, in open_binary
#     return open(fname, "rb", buffering=FILE_READ_BUFFER_SIZE)
# FileNotFoundError: [Errno 2] No such file or directory: '/proc/32885/stat'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/__init__.py", line 361, in _init
#     self.create_time()
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/__init__.py", line 714, in create_time
#     self._create_time = self._proc.create_time()
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_pslinux.py", line 1642, in wrapper
#     return fun(self, *args, **kwargs)
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_pslinux.py", line 1852, in create_time
#     ctime = float(self._parse_stat_file()['create_time'])
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/_pslinux.py", line 1649, in wrapper
#     raise NoSuchProcess(self.pid, self._name)
# psutil.NoSuchProcess: process no longer exists (pid=32885)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.9/threading.py", line 1286, in run
#     self.function(*self.args, **self.kwargs)
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/PyFoam/Execution/FoamThread.py", line 86, in getLinuxMem
#     me=psutil.Process(thrd.threadPid)
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/__init__.py", line 332, in __init__
#     self._init(pid)
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/__init__.py", line 373, in _init
#     raise NoSuchProcess(pid, msg='process PID not found')
# psutil.NoSuchProcess: process PID not found (pid=32885)
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Exception in thread Thread-15528:
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.9/threading.py", line 1286, in run
#     self.function(*self.args, **self.kwargs)
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/PyFoam/Execution/FoamThread.py", line 87, in getLinuxMem
#     procs=[me]+me.children(True)
#   File "/home/ryley/WDK/ML/rans_tuner/tuner/lib/python3.9/site-packages/psutil/__init__.py", line 277, in wrapper
#     raise NoSuchProcess(self.pid, self._name, msg=msg)
# psutil.NoSuchProcess: process no longer exists (pid=657190)
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json
# Saving suggestion to foam/gridsearch/tuner/suggestion.json

# %% [markdown]
# # Bayesian optimization

# %%
foamdir = '/home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_template'
tunerdir = os.path.join(foamdir,'tuner')
ref_df = pd.read_csv(os.path.join(tunerdir,'refdata.csv'))

ref_df.describe()
foamLoss = computeFoamFieldLossFunc(foamdir=foamdir,
                                    ref_df=ref_df,
                                    interp_method='nearest',read_cell_centres=False)
foamLoss.foam_general_loss_function(foamtime = '0',
                                    coef_default_dict={'a1':0.31,'betaStar':0.09},
                                    coef_dict = {'a1':0.32, 'betaStar':0.15},
                                    error_calc_fields=[],
                                    error_calc_intparams=['Cl','Cd'])
# Out:
# 1.0209
# 1.103368
# 0.01928
# 0.009221445
# error_term 0.602488988414949
# coef_term 0.34946236559139787
# score 0.7077626019820773
# 0.7077626019820773

# %%
# Run simulation loop
foamdir = '/home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter'
savedir = '/home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter_opt'

tunerdir = os.path.join(foamdir,'tuner')
iterations=50
n_points_sampled = 4
utility = 'poi'
xi = 0.1
ref_df = pd.read_csv(os.path.join(tunerdir,'refdata.csv'))


initialize(directory = tunerdir,
           coeff_bounds = None,
           coeff_default = None,
           restart = True)

foamLoss = computeFoamFieldLossFunc(foamdir=foamdir,
                                    ref_df=ref_df,
                                    interp_method='nearest',
                                    read_cell_centres=False)
np.random.seed(7)
a1_rand = np.random.uniform(.248, .372, size=(n_points_sampled))
betaStar_rand = np.random.uniform(.072, .108, size=(n_points_sampled))
score_best = 1E6 

for i in range(iterations):
    if i == 0:
        search_point=load_coeff_default(directory=tunerdir)
        write_suggestion(directory=tunerdir, suggestion=search_point)
    elif i < n_points_sampled:
        search_point = {"a1": a1_rand[i], "betaStar": betaStar_rand[i]}
        write_suggestion(directory=tunerdir, suggestion=search_point)
    else:
        suggest(directory=tunerdir, random_state=7,utility_kind = utility, xi=xi)
    
    search_point = load_suggestion(directory=tunerdir)
    print(search_point)
    set_foam_coef(foamdir,search_point)
    last_time = run_until_convergence(case=foamdir, n_proc = 8)
    score = -foamLoss.foam_general_loss_function(foamtime=last_time,
                                                   coef_default_dict = load_coeff_default(directory=tunerdir),
                                                   coef_dict=search_point,
                                                   error_calc_fields=[],
                                                   error_calc_intparams=['Cl'],
                                                   error_type = 'mape'
                                                  )
                                                   
    register_score(score=score, directory=tunerdir)
    if abs(score) < abs(score_best):   
        score_best = score
        os.system(f'rm -r {savedir}')
        os.system(f'cp -r {foamdir} {savedir}')
# Out:
# Did not get coefficient bounds dict for initialization, assuming coeff_bounds.json exists in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner
# Did not get coefficient default dict for initialization, assuming coeff_default.json exists in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner or is not needed
# Removing old history and suggestion files....
# Could not remove a file, it might not exist to start....
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.31, 'betaStar': 0.09}
# 1.0209
# 1.103373
# error_term 0.08078460182192186
# coef_term 0.0
# score 0.08078460182192186
# No history file exists at /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json, creating and registering first point
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.3447099302377742, 'betaStar': 0.09138585133477561}
# rm: cannot remove '/home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter_opt': No such file or directory
# 1.0209
# 1.104142
# error_term 0.08153785875208154
# coef_term 0.06368293253010965
# score 0.08413414373086074
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.3023627446986708, 'betaStar': 0.09004033669175776}
# 1.0209
# 1.103223
# error_term 0.08063767264178681
# coef_term 0.012542246443808858
# score 0.08114336142325104
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.3377096820510367, 'betaStar': 0.07459384080095141}
# 1.0209
# 1.113117
# error_term 0.0903291213635028
# coef_term 0.1302828088942359
# score 0.09621328719159553
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.3716913111159611, 'betaStar': 0.10739517581007829}
# 1.0209
# 1.106088
# error_term 0.08344401998236854
# coef_term 0.19614198031470914
# score 0.09162745764474951
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.3023664693596941, 'betaStar': 0.09008447261706655}
# 1.0209
# 1.103226
# error_term 0.08064061122538949
# coef_term 0.012781438511078208
# score 0.08115596273232602
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.26910385184437047, 'betaStar': 0.07210125185473475}
# 1.0209
# 1.098725
# error_term 0.07623175629346658
# coef_term 0.16539901897919151
# score 0.08253608514646667
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.2606552794311635, 'betaStar': 0.10784197206850471}
# 1.0209
# 0.9654317
# error_term 0.054332745616612714
# coef_term 0.17871032602924275
# score 0.0591876569582171
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.37180730095500497, 'betaStar': 0.07298306688363987}
# 1.0209
# 1.113474
# error_term 0.09067881281222467
# coef_term 0.1942277124018295
# score 0.09948498200014073
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.28423171758227406, 'betaStar': 0.10799785456137745}
# 1.0209
# 1.036242
# error_term 0.01502791654422587
# coef_term 0.14154982673158323
# score 0.0160915160357118
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.275892526169531, 'betaStar': 0.09401698698176221}
# 1.0209
# 1.06824
# error_term 0.046370849250661345
# coef_term 0.07732864890839594
# score 0.04816374681130562
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.3286505783476697, 'betaStar': 0.10790234158682718}
# 1.0209
# 1.103721
# error_term 0.08112547751983548
# coef_term 0.12953903124026345
# score 0.08637993540324712
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.2905320334282349, 'betaStar': 0.07211525769507833}
# 1.0209
# 1.106061
# error_term 0.08341757272994421
# coef_term 0.1307596255552791
# score 0.08887139801739309
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.3012715615450442, 'betaStar': 0.10790235289381722}
# 1.0209
# 1.064472
# error_term 0.042679988245665754
# coef_term 0.11353564261701365
# score 0.04510283819184488
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.260050585342527, 'betaStar': 0.08742859575390859}
# 1.0209
# 1.063914
# error_term 0.042133411695562846
# coef_term 0.09484915117313453
# score 0.044131570863239024
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.3169371501612612, 'betaStar': 0.07207916516134091}
# 1.0209
# 1.111898
# error_term 0.08913507689293775
# coef_term 0.110749145421108
# score 0.09407089368940653
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.3511241240718689, 'betaStar': 0.10785933217937979}
# 1.0209
# 1.105808
# error_term 0.0831697521794495
# coef_term 0.1655477444816476
# score 0.09005403462065223
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.3719539615663918, 'betaStar': 0.09000314018345838}
# 1.0209
# 1.104287
# error_term 0.08167989029287893
# coef_term 0.09994318992558
# score 0.0857615646871998
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.3538362076900751, 'betaStar': 0.07206436375427669}
# 1.0209
# 1.11329
# error_term 0.090498579684592
# coef_term 0.17034598437779547
# score 0.0982066145051741
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.2731595426780822, 'betaStar': 0.10757731984446572}
# 1.0209
# 1.012527
# error_term 0.008201586835145425
# coef_term 0.15707186936840464
# score 0.00884570612313722
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.32719737808997623, 'betaStar': 0.08989551409997093}
# 1.0209
# 1.103652
# error_term 0.08105789009697342
# coef_term 0.028318183819119568
# score 0.08220559621285146
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.3151943963809719, 'betaStar': 0.10795293125776058}
# 1.0209
# 1.085553
# error_term 0.06332941522186314
# coef_term 0.10811656566654575
# score 0.0667528946615924
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.2603719639672363, 'betaStar': 0.07249012978344127}
# 1.0209
# 1.095231
# error_term 0.07280928592418469
# coef_term 0.17732227616634302
# score 0.07926464007724594
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.3591286013488343, 'betaStar': 0.09343068749365323}
# 1.0209
# 1.104525
# error_term 0.08191301792536004
# coef_term 0.0982990545596342
# score 0.08593900403445467
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.28566140194850786, 'betaStar': 0.08536240475112453}
# 1.0209
# 1.102234
# error_term 0.0796689195807621
# coef_term 0.06502022135816644
# score 0.08225896497401565
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.30382417864791256, 'betaStar': 0.07247693728334484}
# 1.0209
# 1.109489
# error_term 0.08677539425996673
# coef_term 0.10731135060664818
# score 0.09143138663869745
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.28930713907061745, 'betaStar': 0.09869768119140063}
# 1.0209
# 1.075162
# error_term 0.053151141149965754
# coef_term 0.08169603320750224
# score 0.05532225984616787
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.264413001849039, 'betaStar': 0.09813414660643222}
# 1.0209
# 1.020646
# error_term 0.00024880007836220635
# coef_term 0.11871711974158565
# score 0.0002635684927095273
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.27015711553834454, 'betaStar': 0.08481829481368748}
# 1.0209
# 1.086045
# error_term 0.06381134293270645
# coef_term 0.09304996790870737
# score 0.06678016463875638
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.33873325280055844, 'betaStar': 0.10222869199199042}
# 1.0209
# 1.105205
# error_term 0.08257909687530618
# coef_term 0.11428113386321309
# score 0.08729771328746123
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.36103756480540594, 'betaStar': 0.0822157574421544}
# 1.0209
# 1.103686
# error_term 0.0810911940444706
# coef_term 0.12556444489997617
# score 0.0861822794277057
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.3197833363587284, 'betaStar': 0.09833819739176192}
# 1.0209
# 1.104274
# error_term 0.08166715643060052
# coef_term 0.06210289361526439
# score 0.08420303979443589
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.2931020884843064, 'betaStar': 0.10791807159982167}
# 1.0209
# 1.051219
# error_term 0.029698305416789094
# coef_term 0.1267995382142857
# score 0.031581171123086935
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.32809694651894594, 'betaStar': 0.07226938760423887}
# 1.0209
# 1.112834
# error_term 0.09005191497698128
# coef_term 0.12769202561632767
# score 0.09580137069400133
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.36148398976110496, 'betaStar': 0.10799730259175114}
# 1.0209
# 1.10594
# error_term 0.08329904985796847
# coef_term 0.18302370756168998
# score 0.0909219003286542
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.27915280421474475, 'betaStar': 0.07215822083319788}
# 1.0209
# 1.102198
# error_term 0.07963365657752973
# coef_term 0.14887453696024422
# score 0.08556136845224516
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.3191780669737534, 'betaStar': 0.08182676778033324}
# 1.0209
# 1.102728
# error_term 0.0801528063473406
# coef_term 0.06021017949344984
# score 0.08256581377587915
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.2600225693516763, 'betaStar': 0.0967192328060244}
# 1.0209
# 1.013891
# error_term 0.006865510823782762
# coef_term 0.11793783025477958
# score 0.007270362548856583
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.34816612611575737, 'betaStar': 0.08133660092187957}
# 1.0209
# 1.113121
# error_term 0.09033303947497318
# coef_term 0.10968826280708775
# score 0.09528727656202013
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.2770175356243371, 'betaStar': 0.10230642057786263}
# 1.0209
# 1.035955
# error_term 0.014746792046233756
# coef_term 0.12156652639690099
# score 0.015643150188512797
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.33586272898536806, 'betaStar': 0.08424078520046914}
# 1.0209
# 1.103442
# error_term 0.08085218924478413
# coef_term 0.07370971678382959
# score 0.08383198523007694
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.3078488249675204, 'betaStar': 0.10128270741476067}
# 1.0209
# 1.101896
# error_term 0.07933783916152422
# coef_term 0.06615134500894214
# score 0.08196199154684318
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.37194717301245556, 'betaStar': 0.09858045424729209}
# 1.0209
# 1.105313
# error_term 0.0826848858850035
# coef_term 0.14758398544411377
# score 0.08878636838245378
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.29594771420796895, 'betaStar': 0.08092292925662721}
# 1.0209
# 1.101537
# error_term 0.07898618865706737
# coef_term 0.07309314788043653
# score 0.08187286324107891
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.36366046955214737, 'betaStar': 0.07210076783838756}
# 1.0209
# 1.11338
# error_term 0.09058673719267325
# coef_term 0.185989323114572
# score 0.09901082015948472
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.30875766785905434, 'betaStar': 0.08014066008688248}
# 1.0209
# 1.102048
# error_term 0.07948672739739446
# coef_term 0.056777872146084964
# score 0.08174327102013444
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.35128625663244945, 'betaStar': 0.09926594996517507}
# 1.0209
# 1.105173
# error_term 0.08254775198354398
# coef_term 0.11806823631047891
# score 0.08742088572758992
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.2664123986976188, 'betaStar': 0.09206343453124725}
# 1.0209
# 1.056121
# error_term 0.03449995102360679
# coef_term 0.08176610791937201
# score 0.03591041438291143
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.3309381042402387, 'betaStar': 0.09816553600931993}
# 1.0209
# 1.104621
# error_term 0.08200705260064665
# coef_term 0.07913522481201901
# score 0.08525187587250828
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
# Saving suggestion to /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/suggestion.json
# {'a1': 0.268658337781859, 'betaStar': 0.10330383169372223}
# 1.0209
# 1.013678
# error_term 0.0070741502595747284
# coef_term 0.14059027642807498
# score 0.007571428629818404
# Registering score in /home/ryley/ML/foam/run/turbo-rans/bayesian_a1_betaStar_airfoil/airfoil_50iter/tuner/history.json
